# %% [markdown]
# ### Dataset Information
# The dataset format is patterned to match closely with the classic MNIST. Each training and test case represents a label (0-25) as a one-to-one map for each alphabetic letter A-Z (and no cases for 9=J or 25=Z because of gesture motions).<br> The training data (27,455 cases) and test data (7172 cases) are approximately half the size of the standard MNIST but otherwise similar with a header row of label, pixel1,pixel2….pixel784 which represent a single 28x28 pixel image with grayscale values between 0-255.

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image

import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator as Imgen
from keras.preprocessing import image
from keras.models import Sequential
from keras.preprocessing import image
from keras.layers import MaxPool2D,Conv2D,Dense,Dropout,Flatten

from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# ## Data

# %%
train_df = pd.read_csv('D:/ML-DL-NLP/Sign Language Prediction/Images/train.csv')
test_df = pd.read_csv('D:/ML-DL-NLP/Sign Language Prediction/Images/test.csv')

# %%
train_df.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# 0       206       204       203       202
# 1       175       103       135       149
# 2       198       195       194       195
# 3       225       222       229       163
# 4       157       163       164       179
#
# [5 rows x 785 columns]

# %%
test_df.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      6     149     149     150     150     150     151     151     150
# 1      5     126     128     131     132     133     134     135     135
# 2     10      85      88      92      96     105     123     135     143
# 3      0     203     205     207     206     207     209     210     209
# 4      3     188     191     193     195     199     201     202     203
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     151  ...       138       148       127        89        82        96
# 1     136  ...        47       104       194       183       186       184
# 2     147  ...        68       166       242       227       230       227
# 3     210  ...       154       248       247       248       253       236
# 4     203  ...        26        40        64        48        29        46
#
#    pixel781  pixel782  pixel783  pixel784
# 0       106       112       120       107
# 1       184       184       182       180
# 2       226       225       224       222
# 3       230       240       253       255
# 4        49        46        46        53
#
# [5 rows x 785 columns]

# %%
test_df.shape
# Out:
# (7172, 785)

# %%
train_df.label.value_counts()
# Out:
# 17    1294
# 16    1279
# 11    1241
# 22    1225
# 5     1204
# 18    1199
# 3     1196
# 14    1196
# 19    1186
# 23    1164
# 8     1162
# 20    1161
# 13    1151
# 2     1144
# 0     1126
# 24    1118
# 10    1114
# 6     1090
# 15    1088
# 21    1082
# 12    1055
# 7     1013
# 1     1010
# 4      957
# Name: label, dtype: int64

# %% [markdown]
# ### Taking a look at  the signs

# %%
plt.figure(figsize=(15,10))
plt.imshow(Image.open('D:/ML-DL-NLP/Sign Language Prediction/Images/signs.png'))
plt.axis('off');

# %%
alp = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

pred_class = []
for i in alp:
    pred_class.append(i)

# %% [markdown]
# ### Distribution of number of data points

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_df,x='label');

# %% [markdown]
# ### Splitting target and data values

# %%
y_train = train_df['label']
x_train = train_df.drop(columns=['label'])

y_test = test_df['label']
x_test = test_df.drop(columns=['label'])

print(x_train.shape,y_train.shape)
# Out:
# (27455, 784) (27455,)

# %%
x_train.head()
# Out:
#    pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0     107     118     127     134     139     143     146     150     153
# 1     155     157     156     156     156     157     156     158     158
# 2     187     188     188     187     187     186     187     188     187
# 3     211     211     212     212     211     210     211     210     210
# 4     164     167     170     172     176     179     180     184     185
#
#    pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0      156  ...       207       207       207       207       206       206
# 1      157  ...        69       149       128        87        94       163
# 2      186  ...       202       201       200       199       198       199
# 3      211  ...       235       234       233       231       230       226
# 4      186  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# 0       206       204       203       202
# 1       175       103       135       149
# 2       198       195       194       195
# 3       225       222       229       163
# 4       157       163       164       179
#
# [5 rows x 784 columns]

# %%
x_train.shape[0]
# Out:
# 27455

# %% [markdown]
# ### Reshaping data values

# %%
x_train = x_train.values.reshape(x_train.shape[0],28,28,1)
x_test = x_test.values.reshape(x_test.shape[0],28,28,1)

print(x_train.shape,x_test.shape)
# Out:
# (27455, 28, 28, 1) (7172, 28, 28, 1)

# %% [markdown]
# **Image Data Generator**

# %%
traingen = Imgen(rescale = 1./255,
                zoom_range=0.2,
                 shear_range=0.2,
                 brightness_range=[0.85,1.20],
                 rotation_range=20,
                 validation_split=0.2
                )
testgen = Imgen(rescale = 1./255)

# %%
train_ds = traingen.flow(x_train,y_train,
                        batch_size = 32,
                        subset='training'
                        )

val_ds = traingen.flow(x_train,y_train,
                        batch_size = 32,
                        subset='validation'
                        )

test_ds = testgen.flow(x_test,y_test,
                       batch_size = 32,
                       shuffle = False
                      )

# %% [markdown]
# - Using one batch to visualize

# %%
x,y = next(train_ds)

# %%
#plot function
def plot_images(images_arr,labels):
    plt.figure(figsize=(15,10))
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images_arr[i])
        plt.title(pred_class[(labels[i])])
        plt.axis('off')

# %%
plot_images(x,y)

# %% [markdown]
# ## Model

# %%
model = Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)),
    MaxPool2D(2,2),
    
    Conv2D(32,(3,3),activation='relu'),
    MaxPool2D(2,2),
    
    Conv2D(128,(3,3),activation='relu'),
    MaxPool2D(2,2),
    
    Flatten(),
    
    Dense(128,activation='relu'),
    Dropout(0.5),
    
    Dense(64,activation='relu'),
    Dropout(0.5),
    
    Dense(25,activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         36992
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 25)                1625
#
# =================================================================
# Total params: 72,953
# Trainable params: 72,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#callbacks
my_calls = [keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=3),
            keras.callbacks.ModelCheckpoint("Model.h5",verbose=1,save_best_only=True)]

# %% [markdown]
# **Train**

# %%
hist = model.fit(train_ds, epochs=21, validation_data=val_ds, callbacks=my_calls)
# Out:
# Epoch 1/21
# 687/687 [==============================] - ETA: 0s - loss: 2.7136 - accuracy: 0.1470
# Epoch 1: val_loss improved from inf to 1.77285, saving model to Model.h5
# 687/687 [==============================] - 28s 40ms/step - loss: 2.7136 - accuracy: 0.1470 - val_loss: 1.7728 - val_accuracy: 0.4094
# Epoch 2/21
# 686/687 [============================>.] - ETA: 0s - loss: 1.6717 - accuracy: 0.4114
# Epoch 2: val_loss improved from 1.77285 to 0.99053, saving model to Model.h5
# 687/687 [==============================] - 27s 40ms/step - loss: 1.6716 - accuracy: 0.4114 - val_loss: 0.9905 - val_accuracy: 0.6793
# Epoch 3/21
# 687/687 [==============================] - ETA: 0s - loss: 1.1097 - accuracy: 0.6072
# Epoch 3: val_loss improved from 0.99053 to 0.68225, saving model to Model.h5
# 687/687 [==============================] - 27s 39ms/step - loss: 1.1097 - accuracy: 0.6072 - val_loss: 0.6823 - val_accuracy: 0.7583
# Epoch 4/21
# 686/687 [============================>.] - ETA: 0s - loss: 0.8335 - accuracy: 0.7020
# Epoch 4: val_loss improved from 0.68225 to 0.51736, saving model to Model.h5
# 687/687 [==============================] - 27s 39ms/step - loss: 0.8333 - accuracy: 0.7020 - val_loss: 0.5174 - val_accuracy: 0.8226
# Epoch 5/21
# 687/687 [==============================] - ETA: 0s - loss: 0.6670 - accuracy: 0.7600
# Epoch 5: val_loss improved from 0.51736 to 0.37203, saving model to Model.h5
# 687/687 [==============================] - 27s 40ms/step - loss: 0.6670 - accuracy: 0.7600 - val_loss: 0.3720 - val_accuracy: 0.8791
# Epoch 6/21
# 687/687 [==============================] - ETA: 0s - loss: 0.5467 - accuracy: 0.8059
# Epoch 6: val_loss improved from 0.37203 to 0.29301, saving model to Model.h5
# 687/687 [==============================] - 27s 39ms/step - loss: 0.5467 - accuracy: 0.8059 - val_loss: 0.2930 - val_accuracy: 0.9024
# Epoch 7/21
# 686/687 [============================>.] - ETA: 0s - loss: 0.4777 - accuracy: 0.8318
# Epoch 7: val_loss improved from 0.29301 to 0.28610, saving model to Model.h5
# 687/687 [==============================] - 27s 40ms/step - loss: 0.4783 - accuracy: 0.8318 - val_loss: 0.2861 - val_accuracy: 0.8973
# Epoch 8/21
# 686/687 [============================>.] - ETA: 0s - loss: 0.3970 - accuracy: 0.8621
# Epoch 8: val_loss improved from 0.28610 to 0.16326, saving model to Model.h5
# 687/687 [==============================] - 27s 39ms/step - loss: 0.3966 - accuracy: 0.8623 - val_loss: 0.1633 - val_accuracy: 0.9492
# Epoch 9/21
# 686/687 [============================>.] - ETA: 0s - loss: 0.3585 - accuracy: 0.8774
# Epoch 9: val_loss improved from 0.16326 to 0.13633, saving model to Model.h5
# 687/687 [==============================] - 27s 39ms/step - loss: 0.3586 - accuracy: 0.8775 - val_loss: 0.1363 - val_accuracy: 0.9550
# Epoch 10/21
# 687/687 [==============================] - ETA: 0s - loss: 0.3148 - accuracy: 0.8968
# Epoch 10: val_loss improved from 0.13633 to 0.11040, saving model to Model.h5
# 687/687 [==============================] - 27s 40ms/step - loss: 0.3148 - accuracy: 0.8968 - val_loss: 0.1104 - val_accuracy: 0.9689
# Epoch 11/21
# 687/687 [==============================] - ETA: 0s - loss: 0.2880 - accuracy: 0.9058
# Epoch 11: val_loss did not improve from 0.11040
# 687/687 [==============================] - 27s 39ms/step - loss: 0.2880 - accuracy: 0.9058 - val_loss: 0.1262 - val_accuracy: 0.9598
# Epoch 12/21
# 686/687 [============================>.] - ETA: 0s - loss: 0.2506 - accuracy: 0.9218
# Epoch 12: val_loss improved from 0.11040 to 0.08919, saving model to Model.h5
# 687/687 [==============================] - 27s 40ms/step - loss: 0.2507 - accuracy: 0.9218 - val_loss: 0.0892 - val_accuracy: 0.9698
# Epoch 13/21
# 686/687 [============================>.] - ETA: 0s - loss: 0.2308 - accuracy: 0.9268
# Epoch 13: val_loss improved from 0.08919 to 0.07215, saving model to Model.h5
# 687/687 [==============================] - 27s 39ms/step - loss: 0.2308 - accuracy: 0.9268 - val_loss: 0.0722 - val_accuracy: 0.9758
# Epoch 14/21
# 687/687 [==============================] - ETA: 0s - loss: 0.2263 - accuracy: 0.9300
# Epoch 14: val_loss improved from 0.07215 to 0.07047, saving model to Model.h5
# 687/687 [==============================] - 27s 39ms/step - loss: 0.2263 - accuracy: 0.9300 - val_loss: 0.0705 - val_accuracy: 0.9776
# Epoch 15/21
# 686/687 [============================>.] - ETA: 0s - loss: 0.2012 - accuracy: 0.9377
# Epoch 15: val_loss improved from 0.07047 to 0.06495, saving model to Model.h5
# 687/687 [==============================] - 27s 40ms/step - loss: 0.2012 - accuracy: 0.9377 - val_loss: 0.0650 - val_accuracy: 0.9796
# Epoch 16/21
# 686/687 [============================>.] - ETA: 0s - loss: 0.1832 - accuracy: 0.9440
# Epoch 16: val_loss improved from 0.06495 to 0.04980, saving model to Model.h5
# 687/687 [==============================] - 27s 39ms/step - loss: 0.1831 - accuracy: 0.9440 - val_loss: 0.0498 - val_accuracy: 0.9862
# Epoch 17/21
# 686/687 [============================>.] - ETA: 0s - loss: 0.1666 - accuracy: 0.9477
# Epoch 17: val_loss improved from 0.04980 to 0.04837, saving model to Model.h5
# 687/687 [==============================] - 27s 40ms/step - loss: 0.1667 - accuracy: 0.9476 - val_loss: 0.0484 - val_accuracy: 0.9840
# Epoch 18/21
# 687/687 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.9514
# Epoch 18: val_loss did not improve from 0.04837
# 687/687 [==============================] - 27s 39ms/step - loss: 0.1568 - accuracy: 0.9514 - val_loss: 0.0813 - val_accuracy: 0.9751
# Epoch 19/21
# 687/687 [==============================] - ETA: 0s - loss: 0.1636 - accuracy: 0.9506
# Epoch 19: val_loss did not improve from 0.04837
# 687/687 [==============================] - 27s 39ms/step - loss: 0.1636 - accuracy: 0.9506 - val_loss: 0.0597 - val_accuracy: 0.9789

# %%
#test
model.evaluate(test_ds,verbose=1)
# Out:
# 225/225 [==============================] - 1s 6ms/step - loss: 0.3165 - accuracy: 0.9136
# [0.31648311018943787, 0.9135527014732361]

# %% [markdown]
# - Visualizing loss and accuracy trends

# %%
plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
plt.plot(hist.epoch,hist.history['accuracy'],label = 'Training')
plt.plot(hist.epoch,hist.history['val_accuracy'],label = 'validation')

plt.title("Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist.epoch,hist.history['loss'],label = 'Training')
plt.plot(hist.epoch,hist.history['val_loss'],label = 'validation')

plt.title("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Test on test data

# %%
preds = model.predict(test_ds)

# %%
preds = [np.argmax(i) for i in preds]

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(preds,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       331
#            1       0.99      0.99      0.99       432
#            2       0.91      1.00      0.95       282
#            3       0.99      1.00      1.00       243
#            4       0.98      0.92      0.95       528
#            5       0.98      0.93      0.96       259
#            6       0.87      0.88      0.87       343
#            7       0.87      1.00      0.93       381
#            8       0.91      0.96      0.93       274
#           10       0.80      1.00      0.89       265
#           11       1.00      1.00      1.00       209
#           12       0.85      0.89      0.87       373
#           13       0.87      0.94      0.91       269
#           14       0.86      0.93      0.89       227
#           15       1.00      1.00      1.00       347
#           16       1.00      0.81      0.90       202
#           17       0.90      0.42      0.57       312
#           18       0.89      0.86      0.88       256
#           19       0.75      0.89      0.82       208
#           20       0.73      0.92      0.81       209
#           21       0.88      0.93      0.91       330
#           22       1.00      0.96      0.98       214
#           23       1.00      0.77      0.87       346
#           24       0.92      0.92      0.92       332
#
#     accuracy                           0.91      7172
#    macro avg       0.91      0.91      0.91      7172
# weighted avg       0.92      0.91      0.91      7172

# %% [markdown]
# #### Confusion Matrix

# %%
#confusion matrix
plt.figure(figsize=(20,15))
sns.heatmap(confusion_matrix(preds,y_test),fmt='d',annot=True,cmap='Blues');

# %% [markdown]
# **Visualising Results**

# %%
X,Y = next(test_ds)

# %%
#plot function
def test_images(images_arr,labels):
    plt.figure(figsize=(15,10))
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(images_arr[i])
        plt.xlabel("Actual: {}".format(pred_class[(labels[i])]))
        plt.ylabel("Predicted: {}".format(pred_class[preds[i]]))

# %%
test_images(X,Y)
